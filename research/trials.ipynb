# %%
d = {"key":"value","key1": "value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
# d.key

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1": "value1"}

# %%
d2 = ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
# get_product(x = 2, y = "3")

# %% [markdown]
# ### Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1ON1OZvzRmCMeg46eBMGDFQZ2oM9gF5yY/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1ON1OZvzRmCMeg46eBMGDFQZ2oM9gF5yY'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1ON1OZvzRmCMeg46eBMGDFQZ2oM9gF5yY
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1ON1OZvzRmCMeg46eBMGDFQZ2oM9gF5yY&confirm=t&uuid=c814c3b9-dd81-4428-84b1-f3220bede3e6
# To: e:\Tanmoy Saha\Upskill\Tech Stack\Krish Naik Projects\Machine Learning\Chest-Disease-Identification\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:03<00:00, 16.0MB/s]
# 'Chest-CT-Scan-data.zip'
